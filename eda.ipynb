# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os
import os.path as osp

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("test.csv")
train
# Out:
#            converted_training1.png  4  0.48   0.7  0.76  0.98
# 0          converted_training2.png  1  0.41  0.68  0.69  0.96
# 1          converted_training3.png  0  0.34  0.09  0.62  0.37
# 2          converted_training4.png  7  0.06  0.32  0.34  0.60
# 3          converted_training5.png  8  0.69  0.05  0.97  0.33
# 4          converted_training6.png  1  0.56  0.69  0.84  0.97
# ...                            ... ..   ...   ...   ...   ...
# 59994  converted_training59996.png  7  0.69  0.53  0.97  0.81
# 59995  converted_training59997.png  1  0.11  0.48  0.39  0.76
# 59996  converted_training59998.png  6  0.59  0.03  0.87  0.31
# 59997  converted_training59999.png  1  0.44  0.40  0.72  0.68
# 59998  converted_training60000.png  5  0.53  0.52  0.81  0.80
#
# [59999 rows x 6 columns]

# %%
test
# Out:
#           converted_testing1.png  2  0.16  0.43  0.44  0.71
# 0         converted_testing2.png  0  0.29  0.40  0.57  0.68
# 1         converted_testing3.png  4  0.27  0.43  0.55  0.71
# 2         converted_testing4.png  8  0.08  0.46  0.36  0.74
# 3         converted_testing5.png  7  0.31  0.01  0.59  0.29
# 4         converted_testing6.png  6  0.32  0.43  0.60  0.71
# ...                          ... ..   ...   ...   ...   ...
# 9994   converted_testing9996.png  5  0.03  0.60  0.31  0.88
# 9995   converted_testing9997.png  9  0.34  0.49  0.62  0.77
# 9996   converted_testing9998.png  8  0.08  0.19  0.36  0.47
# 9997   converted_testing9999.png  0  0.12  0.06  0.40  0.34
# 9998  converted_testing10000.png  5  0.23  0.55  0.51  0.83
#
# [9999 rows x 6 columns]

# %%
idx = 0
filename = train.iloc[idx, 0]
x1, y1, x2, y2 = bbox = list(map(int, train.iloc[idx, 2:] * 100))
img = cv2.imread("data/train/" + filename)
cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
plt.imshow(img)
plt.show()
